# %% [markdown]
# # Text detection and recognition on medicine Images
#
# We build this project to detect and recognize text on madicine images
#
# Similarity comparation is made both on text and images

# %% [markdown]
# ## CNN Overview
#
# ![CNN](http://personal.ie.cuhk.edu.hk/~ccloy/project_target_code/images/fig3.png)
#
# ## MNIST Dataset Overview
#
# This example is using MNIST handwritten digits. The dataset contains 60,000 examples for training and 10,000 examples for testing. The digits have been size-normalized and centered in a fixed-size image (28x28 pixels) with values from 0 to 1. For simplicity, each image has been flattened and converted to a 1-D numpy array of 784 features (28*28).
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# More info: http://yann.lecun.com/exdb/mnist/

# %%
import os
import cv2
import glob
import spacy
import time
import datetime
import data_helpers
import process_image
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import PIL
from PIL import Image
from random import randint
import matplotlib
import matplotlib.pyplot as plt
import pillowfight
import sys
import pyocr
import pyocr.builders

# %matplotlib inline
print('All tools are imported successfully')
# Out:
# /home/xxliu10/.local/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# All tools are imported successfully

# %%
# Next is to prepare Tesseract OCR tools
tools = pyocr.get_available_tools()
if len(tools) == 0:
    print("No OCR tool found")
    sys.exit(1)
# The tools are returned in the recommended order of usage
tool = tools[0]
print("Will use tool '%s'" % (tool.get_name()))
# Ex: Will use tool 'libtesseract'

langs = tool.get_available_languages()
print("Available languages: %s" % ", ".join(langs))
lang = langs[17]
print("-----Will use language:  '%s'" % (lang))
# Out:
# Will use tool 'Tesseract (sh)'
# Available languages: kor, kor_vert, Thaana, kat_old, Syriac, mri, chr, ron, isl, lao, ind, mal, Arabic, Georgian, Hebrew, pol, Tamil, eng, san, jpn_vert, Japanese_vert, Oriya, oci, Fraktur, nld, mlt, lat, snd, hin, ltz, hat, Japanese, chi_tra_vert, Bengali, mya, spa, sun, msa, nep, Canadian_Aboriginal, Myanmar, srp, Cherokee, osd, cym, hun, ita_old, kir, Sinhala, chi_sim_vert, Vietnamese, iku, Cyrillic, rus, Gurmukhi, Devanagari, cat, pan, heb, que, chi_tra, Tibetan, Telugu, Malayalam, Gujarati, cos, kaz, mon, Ethiopic, syr, hrv, jav, ita, Khmer, pus, kat, Kannada, kur_ara, HanT, ces, ori, ceb, spa_old, chi_sim, slk, jpn, Latin, khm, lit, slv, swe, nor, HanS, Hangul, HanT_vert, swa, Armenian, Thai, sqi, kan, por, srp_latn, mkd, Lao, HanS_vert, hye, sin, lav, Hangul_vert, mar, Greek
# -----Will use language:  'eng'

# %%
#-Load all images files for detection
ftypes = ('images/*.jpg', 'images/*.png','images/*.bmp', 'images/*.jpeg',
          'images/*.JPG', 'images/*.PNG', 'images/*.BMP', 'images/*.JPEG') 
files_grabbed = []
for files in ftypes:
    files_grabbed.extend(glob.glob(files))

print ('There are ' + str(len(files_grabbed)) + ' images loaded')
# Out:
# There are 23 images loaded

# %%
# Get some images to show
randindex = randint(0, len(files_grabbed)-1)
img = cv2.imread(files_grabbed[randindex])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#Detect and recognize text on image
txt = tool.image_to_string(Image.fromarray(img), lang=lang, builder=pyocr.builders.TextBuilder())
print('------Following is raw text------')
print(txt)

print('------Following is cleaned text------')
print(data_helpers.process_raw(txt))
# Out:
# ------Following is raw text------
# Noo 37205-620-83
#
# to
# ard?
# f Stang
#
# fo
#
# sore
#
# MAXIMUM STRENGTH
#
# Urinary
# Pain Relief
#
# Phenazopyridine HCI 97.5 mg
#
# essheatah top Uniaciay Ratio
#
# Prompt Relief of Urinary Pain, Burning & Urgency
#
# More Active Ingredient for
# Maximum Relief
#
#
#
# aN BS
#
#
#
#
#
# ef
#
#
#
# (EZ=)) Urinary Pain Rel
#
# Drug Facts
#
# Active ingredient f ‘in each tablet)
#
# Purpose
# Phenazopyricine Hydrock
#
# Navid 97.5 mg Urinary Analgesic
#
# swith urinary tract
#
# Warnings
# Do ol exteed recommended dosage
#
# ‘When using this product — mi stomach upset may a
#
# ing this product with or after ni
# may reduce stomach u
#
# your uti will become reddish-orange in color. This is ao
#
# should be taken to avoid staining clothing or other items.
#
# et you ae hi
#
# ‘oF breastfeeding,
# In caso ofan overt
#
# Directions
# Adults and children 12 years of ane and over:
# 2 tablets 3 times daly wih a full lass of wat
# hildren under 12 years of age:
# 'MDo not use for more than 2 days (12 tablets) withoul consulting a doctor
#
# Other tnformation
#
# Wihis product may stain contact lenses mi this produot can interfere with labora
#
# ‘cluding urine, glucose (sugar), '$ MUlong term administration of phenazopy..
# riding HCI has induced neaplas
#
# b
#
# Keep oul of reach of
# can Contral Genter rit aay
#
# vas been reported, adequate
# ted.
# and protect from light
#
# Inactive Ingredients
#
# ighesium stearate, microcrystaline
# cellulose, pharmaceutical g
#
# Rev. 2/10 MAXLDA
#
#
#
# Questions or Comments Call 1-800-200-6313, weekdays, 9am-4pm EST
#
# Distributed By ‘Al Leader® Brand “This product isnt
#
# Cardinal Health Porto § manufactured or isuibuted by
# Dublin, Ohio 43017 Ament Ntitn, ic, eer of
# wie myleader.com there steed trademark Azo
# cin 4275913 Standed® Maximum Strength
#
#
#
# satisfaction guarante
# Reon
# Coc LON MUCOOE
# ------Following is cleaned text------
# noo 37205-620-83toard?f stangfosoremaximum strengthurinarypain reliefphenazopyridine hci 97.5 mgessheatah top uniaciay ratioprompt relief of urinary pain, burning & urgencymore active ingredient formaximum relief an bs  ef (ez=)) urinary pain reldrug factsactive ingredient f ‘in each tablet)purposephenazopyricine hydrocknavid 97.5 mg urinary analgesicswith urinary tractwarningsdo ol exteed recommended dosage‘when using this product — mi stomach upset may aing this product with or after nimay reduce stomach uyour uti will become reddish-orange in color. this is aoshould be taken to avoid staining clothing or other items.et you ae hi‘of breastfeeding,in caso ofan overtdirectionsadults and children 12 years of ane and over:2 tablets 3 times daly wih a full lass of wathildren under 12 years of age:'mdo not use for more than 2 days (12 tablets) withoul consulting a doctorother tnformationwihis product may stain contact lenses mi this produot can interfere with labora‘cluding urine, glucose (sugar), '$ mulong term administration of phenazopy..riding hci has induced neaplasbkeep oul of reach ofcan contral genter rit aayvas been reported, adequateted.and protect from lightinactive ingredientsighesium stearate, microcrystalinecellulose, pharmaceutical grev. 2/10 maxlda questions or comments call 1-800-200-6313, weekdays, 9am-4pm estdistributed by ‘al leader® brand “this product isntcardinal health porto § manufactured or isuibuted bydublin, ohio 43017 ament ntitn, ic, eer ofwie myleader.com there steed trademark azocin 4275913 standed® maximum strength satisfaction guarantereoncoc lon mucooe

# %%
newimg = process_image.improve(files_grabbed[randindex])
newimgshow = cv2.cvtColor(newimg, cv2.COLOR_GRAY2RGB)
plt.imshow(newimgshow)

# %%
#Detect and recognize text on image
txt = tool.image_to_string(Image.fromarray(newimg), lang=lang, builder=pyocr.builders.TextBuilder())
print('------Following is raw text------')
print(txt)

print('------Following is cleaned text------')
print(data_helpers.process_raw(txt))
# Out:
# ------Following is raw text------
# Noo 37205-620-53
#
#
#
# MAXIMUM meet,
#
# cae
# Pain Relief
#
# Phenazopyridine HCI 97.5 mg
#
# Renwnalightor Uiinamy Rain
#
# Prompt Relief of Urinary Pain, Burning & Urgency
#
# More Active Ingredient for
# Maximum Relief
#
#
#
#
#
# ef .
#
# a
# ce
# ¢
# a
# >
# ©
# £
# the
# =
#
#
#
# Drug Facts
#
# Active ingredient (in each tablet) Purpose
# chloride 97 5 mg Urinary Analgesic
#
# y and frequency associated with urinary tract
#
#
#
# Warnings
# Do ol exteed recommended dosage
#
# ‘When using this product mi stomach upset may ooou" taking this product with or aftern
# may reduce stomach upset Il your uti will become reddish-orange in color. This is ao
# harm should be taken to avoid staining clothing or other items.
#
# Keep oul of reach of
# et medical ielp ar contact a Poisan Control Genter rghit away
#
# Directions
# 1 Adults and children 12 years of ane and over:
# 2 tablets 3 times daly with a full glass of wat
# [dren under 12 years of age:
# 'MDo not use for more than 2 days (12 tablets) withoul consulting a doctor
#
# Other Information
# this product may stain contact lenses wml this product can interfere with laboratory tests
# ‘cluding urine, glucose (sugar), ‘W long term administration of phenazopy-
# fide HCI has induced nbolast in ats (large stn) and mice ve. Athaugh no association
# en phenazopyridine hydrochloride and humman necplasia as been reported, adequate
# been conducted,
#
# microcrystalline
# Rev. 2/10 MAXLDA.
#
# Questions or Comments Call 1-800-200-6313, weekdays, 9am-4pm EST
#
# Distributed By: toe)
# Cardinal Health Pete
# Dublin, Ohio 43017 Pec
# www.myleader.com
#
# cin 4275913
#
#
#
# “This produ is not
# manufactured or distributed by
# Ameri Mutton, Ie., owners of
# the a stered trademark Az0
# faximum Strength,
#
#
#
# oe
# POEM | Standsa
# ------Following is cleaned text------
# noo 37205-620-53 maximum meet,caepain reliefphenazopyridine hci 97.5 mgrenwnalightor uiinamy rainprompt relief of urinary pain, burning & urgencymore active ingredient formaximum relief  ef .ace¢a>©£the= drug factsactive ingredient (in each tablet) purposechloride 97 5 mg urinary analgesicy and frequency associated with urinary tract warningsdo ol exteed recommended dosage‘when using this product mi stomach upset may ooou" taking this product with or afternmay reduce stomach upset il your uti will become reddish-orange in color. this is aoharm should be taken to avoid staining clothing or other items.keep oul of reach ofet medical ielp ar contact a poisan control genter rghit awaydirections1 adults and children 12 years of ane and over:2 tablets 3 times daly with a full glass of wat[dren under 12 years of age:'mdo not use for more than 2 days (12 tablets) withoul consulting a doctorother informationthis product may stain contact lenses wml this product can interfere with laboratory tests‘cluding urine, glucose (sugar), ‘w long term administration of phenazopy-fide hci has induced nbolast in ats (large stn) and mice ve. athaugh no associationen phenazopyridine hydrochloride and humman necplasia as been reported, adequatebeen conducted,microcrystallinerev. 2/10 maxlda.questions or comments call 1-800-200-6313, weekdays, 9am-4pm estdistributed by: toe)cardinal health petedublin, ohio 43017 pecwww.myleader.comcin 4275913 “this produ is notmanufactured or distributed byameri mutton, ie., owners ofthe a stered trademark az0faximum strength, oepoem | standsa

# %%
#Following we write all recognize all images and write to database.
print('Following we write all recognize all images \n and write all text to database.')
with open ('result.txt', 'w', encoding = 'utf-8') as output:
    count = 1
    for f in files_grabbed:
        newimg = process_image.improve(f)
        txt = tool.image_to_string(Image.fromarray(newimg), lang=lang, builder=pyocr.builders.TextBuilder())
        #txt = pyocr.libtesseract.image_to_string(Image.open(f), lang=lang, builder=pyocr.builders.TextBuilder())
        cleantxt = data_helpers.process_raw(txt)
        #head, tail = os.path.split(f)
        #output.write(tail + '\n')
        output.write(cleantxt + '\n')
        time_str = datetime.datetime.now().isoformat()
        print("{}: image {} processed, total {:g}".format(time_str, count, len(files_grabbed)))
        #print('image ' + str(count) + '/' + str(len(files_grabbed)) + ' is processed')
        count += 1
        #if len(cleantxt) > 7:
        #    print('Image ' + str(count) + ' is processed:  ' + cleantxt)
        #    count += 1
# Out:
# Following we write all recognize all images
#  and write all text to database.
# 2018-07-20T15:42:38.301278: image 1 processed, total 23
# 2018-07-20T15:42:39.617703: image 2 processed, total 23
# 2018-07-20T15:42:41.966763: image 3 processed, total 23
# 2018-07-20T15:42:43.793578: image 4 processed, total 23
# 2018-07-20T15:42:44.477756: image 5 processed, total 23
# 2018-07-20T15:42:45.380493: image 6 processed, total 23
# 2018-07-20T15:42:48.619683: image 7 processed, total 23
# 2018-07-20T15:42:50.336810: image 8 processed, total 23
# 2018-07-20T15:42:51.374398: image 9 processed, total 23
# 2018-07-20T15:42:56.727690: image 10 processed, total 23
# 2018-07-20T15:42:57.613963: image 11 processed, total 23
# 2018-07-20T15:42:59.360146: image 12 processed, total 23
# 2018-07-20T15:43:00.166549: image 13 processed, total 23
# 2018-07-20T15:43:02.203479: image 14 processed, total 23
# 2018-07-20T15:43:03.241836: image 15 processed, total 23
# 2018-07-20T15:43:05.467066: image 16 processed, total 23
# 2018-07-20T15:43:05.913620: image 17 processed, total 23
# 2018-07-20T15:43:06.352575: image 18 processed, total 23
# 2018-07-20T15:43:06.902630: image 19 processed, total 23
# 2018-07-20T15:43:09.435423: image 20 processed, total 23
# 2018-07-20T15:43:12.240848: image 21 processed, total 23
# 2018-07-20T15:43:12.567628: image 22 processed, total 23
# 2018-07-20T15:43:12.924451: image 23 processed, total 23

# %%
#Loat the test image
test_img = cv2.imread('3.jpg')
test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)
plt.imshow(test_img)

# %%
gray_test = process_image.improve('3.jpg')
gray_test = cv2.cvtColor(gray_test, cv2.COLOR_GRAY2RGB)
plt.imshow(gray_test)

# %%
test_txt = tool.image_to_string(Image.fromarray(gray_test), lang=lang, builder=pyocr.builders.TextBuilder())
print('------Following is raw text------')
print(test_txt)

print('------Following is cleaned text------')
clean_test = data_helpers.process_raw(test_txt)
print(clean_test)
# Out:
# ------Following is raw text------
# CN TE Coy M oY TU Ske) ae
#
# a TR
#
# ey eV ae
#
# COLD MAX
#
# OU EE eT a
#
# Pain Reliever-Fever Reducer, Cough Suppressant, Nasal Decongestant
#
# Tonnes 8 fl oz (240 ml)
#
# I
# ------Following is cleaned text------
# cn te coy m oy tu ske) aea trey ev aecold maxou ee et apain reliever-fever reducer, cough suppressant, nasal decongestanttonnes 8 fl oz (240 ml)i

# %%
with open('result.txt', 'r') as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]
print(len(content))
print(content[5])
# Out:
# 23
# activeherb”be active extract liu wei di huang tangar we hsfor professional use ah301e -  5:1 concentrate granulenet wt. 100 g (3.53 oz),

# %%
# get the maximum similar image
max_ratio, target = 0, 0
for index, val in enumerate(content):
    ratio = fuzz.partial_ratio(val, clean_test)
    if ratio > max_ratio:
        max_ratio = ratio
        target = index 
    print(str(ratio))
    
target_img = cv2.imread(files_grabbed[target])
target_img = cv2.cvtColor(target_img, cv2.COLOR_BGR2RGB)
plt.imshow(target_img)
# Out:
# 31
# 24
# 20
# 34
# 31
# 25
# 39
# 30
# 24
# 27
# 41
# 23
# 29
# 26
# 19
# 23
# 0
# 42
# 35
# 25
# 30
# 67
# 43
