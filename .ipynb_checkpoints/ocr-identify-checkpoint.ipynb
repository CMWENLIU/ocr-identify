# %% [markdown]
# # Text detection and recognition on medicine Images
#
# We build this project to detect and recognize text on madicine images
# Similarity comparation is made both on text extracted from images
# To identify the medicine of test image, we select the one with highest similarity score in database

# %% [markdown]
# # Following is the working flow diagram:
# <hr>
# <img src="noteimg/diagram.png" width="800">

# %% [markdown]
# # Following is the example result:
# <hr>
# <img src="noteimg/sampleresult.png" width="800">

# %%
# import all tools and libraries
import os
#import cv2
import glob
#import spacy
import time
import datetime
import data_helpers
import process_image
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import PIL
from PIL import Image
from random import randint
import matplotlib
import matplotlib.pyplot as plt
#import pillowfight
import numpy as np
import pandas as pd
import sys
import pyocr
import pyocr.builders

# %matplotlib inline
print('All tools are imported successfully')
# Out:
# All tools are imported successfully

# %%
# Next is to prepare Tesseract OCR tools
tools = pyocr.get_available_tools()
if len(tools) == 0:
    print("No OCR tool found")
    sys.exit(1)
# The tools are returned in the recommended order of usage
tool = tools[0]
print("Will use tool '%s'" % (tool.get_name()))
# Ex: Will use tool 'libtesseract'

langs = tool.get_available_languages()
print('There are 130 languages available!')
print('We will use following languages:')
print(*langs, sep = '\n')
# Out:
# Will use tool 'Tesseract (sh)'
# There are 130 languages available!
# We will use following languages:
# fra
# eng
# chi_sim
# spa

# %%
# build globle variables:
all_res = [] 
dic = {'file': '-'}
for l in langs:
    dic[l] = '-'
files_grabbed = []

# %%
# ** This step is optional for real dataset
# Clean database, remove images with low quality of text recognition
all_files = [] #create list for all files
# Load all type of available image files
ext = ['jpg', 'png','bmp', 'jpeg','JPG', 'PNG', 'BMP', 'JPEG']

for root, dirs, files in os.walk("images/"):
    for file in files:
        if file.endswith(tuple(ext)):
             all_files.append(os.path.join(root, file))
print ('There are ' + str(len(all_files)) + ' images loaded')
print("Following is deleting low quality images")
count = 1
for f in all_files:
    #if count % 10 == 0 or count > (len(all_files)//10)*10:
    print(str(count) + '/' + str(len(all_files)) + ': ' + f + ' is being processed!')
    try:
        result = data_helpers.ext_txt(f, langs, dic, tool)
        total_length = 0
        for l in langs:
            length = len(result[l])
            if length < 10:
                os.remove(f)
                break
    except:
        os.remove(f)
    count += 1
# Out:
# There are 78 images loaded
# Following is deleting low quality images
# 1/78: images/ABIES NIG. product package/5. grouped_single-oils-5-10-30-4oz_silver-fir_1024x1024.jpg is being processed!
# 2/78: images/ABIES NIG. product package/3. nicotine-web.jpg is being processed!
# 3/78: images/ABIES NIG. product package/7. this-or-that-fir-fv_1024x1024_1f308241-0f3a-4aa4-81fc-6ff2780ad0eb_1024x1024.png is being processed!
# 4/78: images/ABIES NIG. product package/13. 10ml-eo-firneedle-front.jpg is being processed!
# 5/78: images/ABIES NIG. product package/8. 1394616885949.jpg is being processed!
# 6/78: images/ABIES NIG. product package/19. 6760-1.jpg is being processed!
# 7/78: images/ABIES NIG. product package/10. roll-on-bottle_extended-label_sniffles-_-sneezes_3737e897-8c40-4b86-83c3-79740c177f88_1024x1024.jpg is being processed!
# 8/78: images/ABIES NIG. product package/11. 6746-1.jpg is being processed!
# 9/78: images/ABIES NIG. product package/37. 11026_l.jpg is being processed!
# 10/78: images/ABIES NIG. product package/12. bonsai3.jpg is being processed!
# 11/78: images/ABIES NIG. product package/2. 16412-1-1000.jpg is being processed!
# 12/78: images/ABIES NIG. product package/43. web-biz-security-2.0combo_big.png is being processed!
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# 13/78: images/ABIES NIG. product package/6. 139462364635.jpg is being processed!
# 14/78: images/ABIES NIG. product package/4. 9956-1-1000.jpg is being processed!
# 15/78: images/ABIES NIG. product package/33. grouped_ok-for-kids-w-roll-on_pollen-buster_1024x1024.jpg is being processed!
# 16/78: images/ABIES NIG. product package/9. tgc205_fir_organic_handcream_2000x.jpg is being processed!
# 17/78: images/ABIES NIG. product package/31. 20130329_103.jpg is being processed!
# 18/78: images/ABIES NIG. product package/18. cconatural-feeling-my-first-starter-set-01.jpg is being processed!
# 19/78: images/ABIES NIG. product package/50. 10688_l.jpg is being processed!
# 20/78: images/ABIES NIG. product package/1. 3988-1-1000.jpg is being processed!
# 21/78: images/ACETAMINOPHEN product package/40. common-meds_fb.png is being processed!
# 22/78: images/ACETAMINOPHEN product package/10. major-44-519-1.jpg is being processed!
# 23/78: images/ACETAMINOPHEN product package/49. exchange-select-44-334b-1.jpg is being processed!
# 24/78: images/ACETAMINOPHEN product package/22. 91cryzpfocl._sl1500_.jpg is being processed!
# 25/78: images/ACETAMINOPHEN product package/13. assured-1.jpg is being processed!
# 26/78: images/ACETAMINOPHEN product package/28. walgreens-44-391-delisted-1.jpg is being processed!
# 27/78: images/ACETAMINOPHEN product package/36. spl-image-4-label-dichlor.jpg is being processed!
# 28/78: images/ACETAMINOPHEN product package/20. paa021052.jpg is being processed!
# 29/78: images/ACETAMINOPHEN product package/32. s-l1000.jpg is being processed!
# 30/78: images/ACETAMINOPHEN product package/9. equaline-44-449-1.jpg is being processed!
# 31/78: images/ACETAMINOPHEN product package/17. 000718499.jpg is being processed!
# 32/78: images/ACETAMINOPHEN product package/25. a3818b0e-5b77-43eb-bfb1-c954b0354017.jpg is being processed!
# 33/78: images/ACETAMINOPHEN product package/2. tylenol-pm-01.jpg is being processed!
# 34/78: images/ACETAMINOPHEN product package/50. 3bcc0b7b-c292-4237-a3da-2b837febaa03_1.d61deffd28c49ad7e47ae4d81b0d63a6.jpeg is being processed!
# 35/78: images/ACETAMINOPHEN product package/18. careone-44-556-1.jpg is being processed!
# 36/78: images/ACETAMINOPHEN product package/24. tylenol-liver-damage_oho.jpg is being processed!
# 37/78: images/ACETAMINOPHEN product package/7. 141118-otc-7-select.jpg is being processed!
# 38/78: images/ACETAMINOPHEN product package/5. welby-44-175-delisted-1.jpg is being processed!
# 39/78: images/ACETAMINOPHEN product package/37. 71wlj2k5oll.jpg is being processed!
# 40/78: images/ACETAMINOPHEN product package/31. walgreens-44-449-1.jpg is being processed!
# 41/78: images/ACETAMINOPHEN product package/12. 2.3-tylenol-50-hero-callout.jpg is being processed!
# 42/78: images/ACETAMINOPHEN product package/44. 59bd9ce7d551e.image.jpg is being processed!
# 43/78: images/ACETAMINOPHEN product package/14. family-wellness-44-369-delisted-1.jpg is being processed!
# 44/78: images/ACETAMINOPHEN product package/21. exchange-select-44-447-delisted-1.jpg is being processed!
# 45/78: images/ACETAMINOPHEN product package/11. best-choice-44-449-1.jpg is being processed!
# 46/78: images/ACETAMINOPHEN product package/16. exchange-select-44-450-1.jpg is being processed!
# 47/78: images/ACETAMINOPHEN product package/41. family-wellness-44-503a473c-1.jpg is being processed!
# 48/78: images/ACETAMINOPHEN product package/8. exhange-select-44-556-1.jpg is being processed!
# 49/78: images/ACETAMINOPHEN product package/46. 81adhrr-mnl.jpg is being processed!
# 50/78: images/ACETAMINOPHEN product package/19. 71ulncafu9l._sl1500_.jpg is being processed!
# 51/78: images/ACETAMINOPHEN product package/34. s-l1000.jpg is being processed!
# 52/78: images/ACETAMINOPHEN product package/38. 8b7e77b7-185b-4a71-b754-0380c7b32b31_1.f4ab08b7af4b571776e878a3da2eaba3.jpeg is being processed!
# 53/78: images/ACETAMINOPHEN product package/4. c2e3b962-4203-44e4-894c-28e9011c1166-01.jpg is being processed!
# 54/78: images/ACETAMINOPHEN product package/1. rite-aid-44-452-1.jpg is being processed!
# 55/78: images/ACETAMINOPHEN product package/3. tylenol%20pm.jpg is being processed!
# 56/78: images/ACETAMINOPHEN product package/47. tylenol-pill-and-container-with-safety-seal-dw7rb1.jpg is being processed!
# 57/78: images/ACETAMINOPHEN product package/6. main_00300450449108_united%20states_000000000304491000.jpeg is being processed!
# 58/78: images/ACETAMINOPHEN product package/15. extra-strength-acetaminophen-1_fa6fabcf.jpg is being processed!
# 59/78: images/ACONITUM NAP. product package/25. 1002915%20(1).jpg is being processed!
# 60/78: images/ACONITUM NAP. product package/5. aconitum-nap__73416.1510170986.jpg is being processed!
# 61/78: images/ACONITUM NAP. product package/2. aconitum-napellus-30c-by-boiron.jpg is being processed!
# 62/78: images/ACONITUM NAP. product package/3. 71d5qz57dkl._sl1500_.jpg is being processed!
# 63/78: images/ACONITUM NAP. product package/46. aconitum-napellus-30x-homeopathic-formula-for-colds-fever-250-tablets-40987.jpg is being processed!
# 64/78: images/ACONITUM NAP. product package/19. aconitum1.jpg is being processed!
# 65/78: images/ACONITUM NAP. product package/21. aconitumnapellus_30c_497b5a3a-91c4-4966-ba54-653a84bcccdf.jpg is being processed!
# 66/78: images/ACONITUM NAP. product package/11. aconitum-napellus-200k-55g-by-seroyal-extra2.jpg is being processed!
# 67/78: images/ACONITUM NAP. product package/4. aconitum-napellus-30x-250-tablets-by-hylands.jpg is being processed!
# 68/78: images/ACONITUM NAP. product package/6. 71vt-wrij1l.jpg is being processed!
# 69/78: images/ACONITUM NAP. product package/40. 71ph84vjztl._sl1500_.jpg is being processed!
# 70/78: images/ACONITUM NAP. product package/9. aconitum-napellus-200k-55g-by-seroyal.jpg is being processed!
# 71/78: images/ACONITUM NAP. product package/1. aconitum-napellus-200ck-by-boiron.jpg is being processed!
# 72/78: images/ACONITUM NAP. product package/10. 81punzv-btl.jpg is being processed!
# 73/78: images/ACONITUM NAP. product package/41. do0108par_0001_1024x1024.jpeg is being processed!
# 74/78: images/ACONITUM NAP. product package/7. aconitum-napellus-200ck-by-boiron-extra2.jpg is being processed!
# 75/78: images/ACONITUM NAP. product package/42. 81m42qayxxl._sl1500_.jpg is being processed!
# 76/78: images/ACONITUM NAP. product package/8. aconite-30ch-for-fright-supplements_1400x.jpg is being processed!
# 77/78: images/ACONITUM NAP. product package/20. 3.jpg is being processed!
# 78/78: images/ACONITUM NAP. product package/49. file_000_16_.jpeg is being processed!

# %%
files_grabbed = [] #create list for all files
# Load all type of available image files
ext = ['jpg', 'png','bmp', 'jpeg','JPG', 'PNG', 'BMP', 'JPEG']

for root, dirs, files in os.walk("images/"):
    for file in files:
        if file.endswith(tuple(ext)):
             files_grabbed.append(os.path.join(root, file))
print ('There are ' + str(len(files_grabbed)) + ' images loaded')
# Out:
# There are 69 images loaded

# %%
# Get a random image to show
randindex = randint(0, len(files_grabbed)-1)
process_image.improve(files_grabbed[randindex])
list2show = ['ori.jpg','gray.jpg']
plt.figure(figsize=(9,9))
columns = 2
for i, img in enumerate(list2show):
    img = Image.open(img)
    plt.subplot(len(list2show) / columns + 1, columns, i + 1)
    plt.imshow(img,cmap=plt.get_cmap("gray"))    
result = data_helpers.ext_txt(files_grabbed[randindex], langs, dic, tool)
for l in langs:
    print ('------' + l + '\n' + result[l])
# Out:
# ------fra
# &) alamy stock photo Pr
# ------eng
# E)} alamy stock photo ont con
# ------chi_sim
# DW7RB1  www .alamy.com  图 alamy stock photo
# ------spa
# El alamy stock photo _

# %%
#Following we recognize all images and write to database.
print('Following we recognize all images and write all text to database.')
i = 1
for f in files_grabbed:
    result = data_helpers.ext_txt(f, langs, dic, tool)
    time_str = datetime.datetime.now().isoformat()
    if i % 10 == 0 or i > (len(files_grabbed)//10)*10:
        print("{}: {}/{} processed".format(time_str, i, len(files_grabbed),))
    all_res.append(result.copy())
    i += 1
# Out:
# Following we recognize all images and write all text to database.
# 2018-08-28T10:20:58.815737: 10/69 processed
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/lib/python3/dist-packages/PIL/Image.py:918: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# 2018-08-28T10:22:08.231610: 20/69 processed
# 2018-08-28T10:30:56.675232: 30/69 processed
# 2018-08-28T10:34:26.181425: 40/69 processed
# 2018-08-28T10:44:01.638130: 50/69 processed
# 2018-08-28T10:49:58.544823: 60/69 processed
# 2018-08-28T10:50:02.980044: 61/69 processed
# 2018-08-28T10:50:20.454963: 62/69 processed
# 2018-08-28T10:50:30.997877: 63/69 processed
# 2018-08-28T10:50:37.462661: 64/69 processed
# 2018-08-28T10:50:49.899567: 65/69 processed
# 2018-08-28T10:50:55.501931: 66/69 processed
# 2018-08-28T10:51:02.296697: 67/69 processed
# 2018-08-28T10:51:04.871010: 68/69 processed
# 2018-08-28T10:51:29.075108: 69/69 processed

# %%
#Save result to csv file and html file for easy read
df = pd.DataFrame(all_res)
df.to_csv('result.csv', header=True, columns=['file', 'eng', 'fra', 'spa','chi_sim'], index=False)
print('All images have been recognized and saved to result.csv')

with open('result.html', 'w') as outf:
    with open('htmlhead.txt', 'r') as fh:
        for line in fh:
            outf.write(line)
    imghead = '<img src="'
    imgtail = '" onclick="changesize(this)">'
    for item in all_res:
        outf.write(imghead + item['file'] + imgtail)
        outf.write('<p>--English:' + item['eng'] + '</p>' + '\n')
        outf.write('<p>--French:' + item['fra']+ '</p>' + '\n')
        outf.write('<p>--Spanish:' + item['spa'] + '</p>' + '\n')
        outf.write('<p>--Chinese:' + item['chi_sim'] + '</p>' + '\n')
        outf.write('<hr>' + '\n')
    with open('htmltail.txt', 'r') as ft:
        for line in ft:
            outf.write(line)
print('All images have been recognized and saved to result.html')
# Out:
# All images have been recognized and saved to result.csv
# All images have been recognized and saved to result.html

# %%
#Following is our test result
#Put test image as 'test.jpg' in the same foder of code
testf = 'test.jpg'
process_image.improve(testf)
list2show = ['ori.jpg','gray.jpg']
plt.figure(figsize=(15,10))
columns = 2
for i, img in enumerate(list2show):
    img = Image.open(img)
    plt.subplot(len(list2show) / columns + 1, columns, i + 1)
    plt.imshow(img,cmap=plt.get_cmap("gray"))    
result = data_helpers.ext_txt(testf, langs, dic, tool)
for l in langs:
    print ('------' + l + '\n' + result[l])
# Comparing with all records
ratiolist=[]
for res in all_res:
    s = ''
    sum = 0
    for l in langs:
        #s += l + ':' + str(data_helpers.similarity(res[l], result[l])) + ', '
        ratio = fuzz.partial_ratio(res[l], result[l])
        sum += ratio
    ratiolist.append(sum/len(langs))
print(len(ratiolist))
# Out:
# ------fra
# cough suppressant —topical analgesicst
# ------eng
# [tv t lt ntopical analgesict
# ------spa
# cough suppressant —topical analgesicto
# ------chi_sim
# eeointme
# 131

# %%
# Get top N results from database with maximum similarity
N = 5
topN = sorted(range(len(ratiolist)), key=lambda i: ratiolist[i], reverse=True)[:N]
print(topN)
for i,val in enumerate(topN):
    img = Image.open(all_res[val]['file'])
    plt.figure()
    plt.title('Average Ratio: ' + str(ratiolist[val]))
    plt.imshow(img) 
print(all_res[31]['file'])
# Out:
# [59, 54, 65, 127, 37]
# images/Adult_Cough_plus_Nighttime.jpg
