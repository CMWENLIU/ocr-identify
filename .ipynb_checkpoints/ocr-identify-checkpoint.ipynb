# %% [markdown]
# # Text detection and recognition on medicine Images
#
# We build this project to detect and recognize text on madicine images
#
# Similarity comparation is made both on text and images

# %% [markdown]
# Multi-lauguage will be added

# %%
import os
import cv2
import glob
import spacy
import time
import datetime
import data_helpers
import process_image
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import PIL
from PIL import Image
from random import randint
import matplotlib
import matplotlib.pyplot as plt
import pillowfight
import numpy as np
import sys
import pyocr
import pyocr.builders

# %matplotlib inline
print('All tools are imported successfully')
# Out:
# All tools are imported successfully

# %%
# Next is to prepare Tesseract OCR tools
tools = pyocr.get_available_tools()
if len(tools) == 0:
    print("No OCR tool found")
    sys.exit(1)
# The tools are returned in the recommended order of usage
tool = tools[0]
print("Will use tool '%s'" % (tool.get_name()))
# Ex: Will use tool 'libtesseract'

langs = tool.get_available_languages()
print('There are 130 languages available!')
print('We will use following languages:')
print(*langs, sep = '\n')
# Out:
# Will use tool 'Tesseract (sh)'
# There are 130 languages available!
# We will use following languages:
# fra
# eng
# spa
# chi_sim

# %%
# build globle variables:
all_res = []
dic = {'file': '-'}
for l in langs:
    dic[l] = '-'
files_grabbed = []

# %%
#-Load all images files for detection
ftypes = ('images/*.jpg', 'images/*.png','images/*.bmp', 'images/*.jpeg',
          'images/*.JPG', 'images/*.PNG', 'images/*.BMP', 'images/*.JPEG') 

for files in ftypes:
    files_grabbed.extend(glob.glob(files))

print ('There are ' + str(len(files_grabbed)) + ' images loaded')
print(*files_grabbed)
# Out:
# There are 13 images loaded
# images/TB1fWrVJVXXXXaOXXXXXXXXXXXX_!!2-item_pic.jpg images/00011822316453_1.jpg images/1c4b5154305f3a0c27b61a589cae322c--asthma-relief-allergy-relief.jpg images/00011822302944.jpg images/0030045020904_0600.jpg images/00011822315234.jpg images/00300230798150_1_1.jpg images/375e067cb34bc56ae3be98153a54c02a.jpg images/323900003620.jpg images/8oz_coughsyrup_medicinecap__60305.1416078826.jpg images/900 (2).jpg images/71K28aGrOqL._SL1500_.jpg images/300450170057_00591001_benadryl--d-child_allergy.jpg

# %%
# Get a random image to show
randindex = randint(0, len(files_grabbed)-1)
process_image.improve(files_grabbed[randindex])
list2show = ['ori.jpg','gray.jpg']
plt.figure(figsize=(9,9))
columns = 2
for i, img in enumerate(list2show):
    img = Image.open(img)
    plt.subplot(len(list2show) / columns + 1, columns, i + 1)
    plt.imshow(img,cmap=plt.get_cmap("gray"))    
result = data_helpers.ext_txt(files_grabbed[randindex], langs, dic, tool)
for l in langs:
    print ('------' + l + '\n' + result[l])
# Out:
# ------fra
# compare to claritin"*turte) 471/#    s%$èv loratadine orally disintegrating tablet, 10mgä* antihistamines non-drowsy*allergy reliefa relief of% e sneezingü « runny nosey eyes« itchy, waterjose & throat_ hour . itching of narkof scherng corporationfresh mintpen60 b8 disintegratingg pn   4 clartin® sà reistered trader
# ------eng
# compare to claritin™'al & save!    ns§o loratadine orally disintegrating tablet, 10mg§i antihistaminex non-drowsy’allergy relief" relief of% e sneezingu » runny nosey eyeso itchy, watenose & throatj hour < itching of nsarkof schering corporation(720 wlorally60 bs pp c4 lelies   $clrtn® s registred adem:
# ------spa
# compare to claritin"'ene |7    us$e loratadine orally disintegrating tablet, 10mg%¿ antihistaminen non-drowsy"allergy relief. relief ofx * sneezingu * runny nosey eyese itchy, waterose 8: throat- hour - itching 0f narkcof schering corporatin77 tad60 b8 disintegratingv tablets   +claritin? s rgistereo tadem
# ------chi_sim
# 夏鲁胥tes 【clxil c″…″″a/e e 霆'a去发′/″叶e一 lmoufhl   逞荨宁羹塞 loratadine orally disintegrating tablet 100m9姜工 antihistamine羹爹 non-drowsy“allergy relief/ - arelief of昊 * sneezin* ru门门〉w副e吖 eye5~ hour …h…g of nose & throathounirgangsetuntretoeoum0poo

# %%
#Following we recognize all images and write to database.
print('Following we recognize all images \n and write all text to database.')
i = 1
for f in files_grabbed:
    result = data_helpers.ext_txt(f, langs, dic, tool)
    print('file ' + str(i) + ' finished!')
    all_res.append(result.copy())
    i += 1
print(len(all_res))
print(*all_res)
print(type(all_res[0]))
print(*files_grabbed)
# Out:
# Following we recognize all images
#  and write all text to database.
# file 1 finished!
# file 2 finished!
# file 3 finished!
# file 4 finished!
# file 5 finished!
# file 6 finished!
# file 7 finished!
# file 8 finished!
# file 9 finished!
# file 10 finished!
# file 11 finished!
# file 12 finished!
# file 13 finished!
# 13
# {'file': 'images/TB1fWrVJVXXXXaOXXXXXXXXXXXX_!!2-item_pic.jpg', 'fra': 'pophthalmology dropsfor dogs and catsindicationsd keratitis (levofloxacin hcl 0 5*> o conjunctivitiso swelling© epiphora© eyelid inflammation ° n x© opiaimorrosis mniophthalmology drofs', 'eng': '| —ophthalmology dropsfor dogs and catsindicationso keratitis (levofioxacin hcl 0.5*> o conjunctivitiso swellingo epiphorao eyelid inflammation 0 n x5 omitaimorross mniophthalmology drop', 'spa': "——]]ophthalmology dropsfor dogs and catsindications'o keratitis (levofloxacin hcl 05*> o conjunctivitis' swellngl epiphora'l eyelid inflammation o n xel opimalmorross mniophthalmology drofs", 'chi_sim': 'l 去 妻目 痕gmp lnoloacnholosm一〇 minix0phthalmology dropsf0g006s n cafsindicationsd ketts (leofoac hcl05d conoetntisd swelid pprond bleid ntammaton o n x日 amoooss minimmamoloey dwk'} {'file': 'images/00011822316453_1.jpg', 'fra': 'loratadine tabletsusp, 10 mg', 'eng': 'loratadine tabletsusp, 10 mg', 'spa': 'loratadine tabletsu oo', 'chi_sim': 'loratadine tabletsl 朋 l'} {'file': 'images/1c4b5154305f3a0c27b61a589cae322c--asthma-relief-allergy-relief.jpg', 'fra': '— runny nose, sneezing- itchy, watery eyes© sinus pain & pressurere a c qu[ 1804natrabio (30 ml)rp re an t20% usp alcohol', 'eng': 't al (a r clrlgo c al~
# <class 'dict'>
# images/TB1fWrVJVXXXXaOXXXXXXXXXXXX_!!2-item_pic.jpg images/00011822316453_1.jpg images/1c4b5154305f3a0c27b61a589cae322c--asthma-relief-allergy-relief.jpg images/00011822302944.jpg images/0030045020904_0600.jpg images/00011822315234.jpg images/00300230798150_1_1.jpg images/375e067cb34bc56ae3be98153a54c02a.jpg images/323900003620.jpg images/8oz_coughsyrup_medicinecap__60305.1416078826.jpg images/900 (2).jpg images/71K28aGrOqL._SL1500_.jpg images/300450170057_00591001_benadryl--d-child_allergy.jpg

# %%
#Save result to txt file
with open('result.txt', 'w', encoding = 'utf-8') as outf:
    for item in all_res:
        outf.write('--FileName:' + item['file'] + '\n')
        outf.write('--English:' + item['eng'] + '\n')
        outf.write('--Spanish:' + item['spa'] + '\n')
        outf.write('--French:' + item['fra']+ '\n')
        outf.write('--Chinese:' + item['chi_sim'] + '\n')

# %%
#Following is our test result

testf = 'test.jpg'
process_image.improve(testf)
list2show = ['ori.jpg','gray.jpg']
plt.figure(figsize=(15,10))
columns = 2
for i, img in enumerate(list2show):
    img = Image.open(img)
    plt.subplot(len(list2show) / columns + 1, columns, i + 1)
    plt.imshow(img,cmap=plt.get_cmap("gray"))    
result = data_helpers.ext_txt(testf, langs, dic, tool)
for l in langs:
    print ('------' + l + '\n' + result[l])
# get result from all records
for res in all_res:
    s = ''
    sum = 0
    for l in langs:
        #s += l + ':' + str(data_helpers.similarity(res[l], result[l])) + ', '
        ratio = fuzz.partial_ratio(res[l], result[l])
        sum += ratio
        s += l + ':' + str(ratio) + ', '
    s += 'Average: ' + str(sum/len(langs)) + 'file: ' + res['file']
    print (s)
# Out:
# ------fra
# cough suppressant —topical analgesicst
# ------eng
# [tv t lt ntopical analgesict
# ------spa
# cough suppressant —topical analgesicto
# ------chi_sim
# eeointme
# fra:34, eng:32, spa:37, chi_sim:38, Average: 35.25file: images/TB1fWrVJVXXXXaOXXXXXXXXXXXX_!!2-item_pic.jpg
# fra:25, eng:25, spa:27, chi_sim:38, Average: 28.75file: images/00011822316453_1.jpg
# fra:32, eng:36, spa:39, chi_sim:38, Average: 36.25file: images/1c4b5154305f3a0c27b61a589cae322c--asthma-relief-allergy-relief.jpg
# fra:26, eng:43, spa:29, chi_sim:38, Average: 34.0file: images/00011822302944.jpg
# fra:26, eng:32, spa:21, chi_sim:27, Average: 26.5file: images/0030045020904_0600.jpg
# fra:0, eng:0, spa:0, chi_sim:38, Average: 9.5file: images/00011822315234.jpg
# fra:27, eng:30, spa:27, chi_sim:50, Average: 33.5file: images/00300230798150_1_1.jpg
# fra:36, eng:23, spa:50, chi_sim:50, Average: 39.75file: images/375e067cb34bc56ae3be98153a54c02a.jpg
# fra:89, eng:27, spa:58, chi_sim:25, Average: 49.75file: images/323900003620.jpg
# fra:38, eng:39, spa:34, chi_sim:38, Average: 37.25file: images/8oz_coughsyrup_medicinecap__60305.1416078826.jpg
# fra:29, eng:29, spa:29, chi_sim:38, Average: 31.25file: images/900 (2).jpg
# fra:38, eng:36, spa:38, chi_sim:50, Average: 40.5file: images/71K28aGrOqL._SL1500_.jpg
# fra:20, eng:13, spa:20, chi_sim:27, Average: 20.0file: images/300450170057_00591001_benadryl--d-child_allergy.jpg

# %%
#-Load all images for test
testypes = ('testimg/*.jpg', 'testimg/*.png','testimg/*.bmp', 'testimg/*.jpeg',
          'testimg/*.JPG', 'testimg/*.PNG', 'testimg/*.BMP', 'testimg/*.JPEG') 
test_grabbed = []
for files in testypes:
    test_grabbed.extend(glob.glob(files))

print ('There are ' + str(len(test_grabbed)) + ' images loaded')
plt.figure(figsize=(15,10))
columns = 3
for i, img in enumerate(test_grabbed):
    img = cv2.imread(img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(len(test_grabbed) / columns + 1, columns, i + 1)
    plt.imshow(img)  
    plt.title('This is the text')
# Out:
# There are 5 images loaded

# %%
gray_test = process_image.improve('3.jpg')
gray_test = cv2.cvtColor(gray_test, cv2.COLOR_GRAY2RGB)
plt.imshow(gray_test)

# %%
test_txt = tool.image_to_string(Image.fromarray(gray_test), lang=lang, builder=pyocr.builders.TextBuilder())
print('------Following is raw text------')
print(test_txt)

print('------Following is cleaned text------')
clean_test = data_helpers.process_raw(test_txt)
print(clean_test)

# %%
with open('result.txt', 'r') as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip() for x in content]
print(len(content))
print(content[5])
# Out:
# 99
# ndc 0220-9325-04su hoarsenessred, dry and sore throat’throatcalmhomeopathic medicine  = non-drowsy@ no known drug interactions@ melts under your tongue  cpv aequick-dissolvingbo .@ n° tabletsmoya cs ete th) neen ec len ects

# %%
# get the maximum similar image
max_ratio, target = 0, 0
for index, val in enumerate(content):
    ratio = fuzz.partial_ratio(val, clean_test)
    if ratio > max_ratio:
        max_ratio = ratio
        target = index 
    print(str(ratio))
    
target_img = cv2.imread(files_grabbed[target])
target_img = cv2.cvtColor(target_img, cv2.COLOR_BGR2RGB)
plt.imshow(target_img)
# Out:
# 31
# 33
# 21
# 24
# 24
# 20
# 27
# 20
# 34
# 31
# 18
# 28
# 30
# 36
# 25
# 24
# 39
# 26
# 46
# 41
# 25
# 0
# 28
# 25
# 35
# 0
# 30
# 37
# 0
# 0
# 29
# 24
# 27
# 0
# 41
# 23
# 20
# 28
# 36
# 32
# 23
# 41
# 38
# 29
# 26
# 0
# 9
# 37
# 24
# 42
# 29
# 0
# 35
# 35
# 0
# 0
# 39
# 26
# 19
# 20
# 18
# 17
# 36
# 29
# 28
# 23
# 41
# 20
# 72
# 17
# 23
# 36
# 14
# 23
# 36
# 0
# 26
# 34
# 0
# 31
# 0
# 42
# 35
# 20
# 35
# 0
# 0
# 28
# 0
# 35
# 26
# 31
# 26
# 0
# 25
# 30
# 67
# 43
# 36
